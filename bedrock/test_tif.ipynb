# %%
import rasterio
import matplotlib.pyplot as plt

# %%
rips = rasterio.open('data/rippability_0-20.tif')

# %%
rips.name
# Out:
# 'data/rippability_0-20.tif'

# %%
rips.count
# Out:
# 1

# %%
rips.width
# Out:
# 391

# %%
rips.height
# Out:
# 187

# %%
rips.bounds
# Out:
# BoundingBox(left=-11466777.235229, bottom=4439462.602803024, right=-10510397.137324901, top=3982063.4255445423)

# %%
rips.transform
# Out:
# Affine(2445.9849051255733, 0.0, -11466777.235229,
#        0.0, 2445.9849051255733, 3982063.4255445423)

# %%
rips.crs
# Out:
# CRS.from_epsg(3857)

# %%
rips.indexes
# Out:
# (1,)

# %%
vals = rips.read(1)

# %%
vals.shape
# Out:
# (187, 391)

# %%
plt.figure(figsize=(16, 9))
c1 = plt.imshow(vals, origin="lower", vmin=1, vmax=4)
plt.colorbar(c1, shrink=0.7)
plt.show()

# %%
rips2 = rasterio.open('data/rippability_0-20_t2.tif')

# %%
vals2 = rips2.read(1)

# %%
plt.figure(figsize=(12, 12))
c1 = plt.imshow(vals2, origin="lower", vmin=1, vmax=4)
plt.colorbar(c1, shrink=0.7)
plt.show()

# %%
rips3 = rasterio.open('data/rippability_0-20_t3.tif')

# %%
vals3 = rips3.read(1)

# %%
plt.figure(figsize=(12, 12))
c1 = plt.imshow(vals3, origin="lower", vmin=1, vmax=4)
plt.colorbar(c1, shrink=0.7)
plt.show()

# %%
rips4 = rasterio.open('data/rippability_0-20_t4.tif')

# %%
vals4 = rips4.read(1)

# %%
plt.figure(figsize=(12, 12))
c1 = plt.imshow(vals4, origin="lower", vmin=1, vmax=4)
plt.colorbar(c1, shrink=0.7)
plt.show()

# %%
rips5 = rasterio.open('data/rippability_0-20_t5.tif')

# %%
vals5 = rips5.read(1)

# %%
plt.figure(figsize=(12, 12))
c1 = plt.imshow(vals5, origin="lower", vmin=1, vmax=4)
plt.colorbar(c1, shrink=0.7)
plt.show()

# %%
diff = vals5 - vals4

# %%
max(diff)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-0607d190ff88> in <module>
# ----> 1 max(diff)
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()

# %%
diff.shape
# Out:
# (1024, 1024)

# %%
import numpy

# %%
numpy.max(diff)
# Out:
# 0.0
